# %% [markdown]
# # TelSMS API - Admin User Scenario
# **User:** Admin (Full Access) | **Base URL:** http://localhost:8000 | **Auth:** Token-based
# Covers all 150+ API endpoints with admin privileges.

# %%
import requests
import json
## Variables
BASE = "https://api.smartsender.lol/"
admin_token = None  # Set after login
project_path = "."

# %%
# 1.1: POST /api/v1/auth/register/ - Register admin user
register_data = {"username": "admin", "email": "admin@telsms.com", "password": "Admin123!","phone_number":"+989374303340"}
response = requests.post(f"{BASE}/api/v1/auth/register/", json=register_data)
print(f"1.1 Register: {response.status_code} - {response.json()}")

# %%
# 1.1: POST /api/v1/auth/register/ - Register admin user
register_data = {"username": "admin", "email": "admin@telsms.com", "password": "Admin123!","phone_number":"+989374303340"}
response = requests.post(f"{BASE}/api/v1/auth/register/", json=register_data)
print(f"1.1 Register: {response.status_code} - {response.json()}")

register_data = {
    "username": f"admin",
    "email": f"admin@telsms.com",
    "password": "Admin123!",
    "phone_number": f"+989374303340"
}
response = requests.post(f"{BASE}/api/v1/auth/register/", json=register_data)
print(f"1.2 Register Repeted User shoud be wrong: {response.status_code} - {response.json()}")

register_data = {
    "username": f"admin1",
    "email": f"admin@telsms.com",
    "password": "Admin123!",
    "phone_number": f"+989374303340"
}
response = requests.post(f"{BASE}/api/v1/auth/register/", json=register_data)
print(f"1.3 Register Repeted Phone User shoud be wrong: {response.status_code} - {response.json()}")

register_data = {
    "username": f"admin",
    "email": f"admin@telsms.com",
    "password": "Admin123!",
    "phone_number": f"+989374303341"
}
response = requests.post(f"{BASE}/api/v1/auth/register/", json=register_data)
print(f"1.4 Register Repeted username User shoud be wrong: {response.status_code} - {response.json()}")

register_data = {
    "username": f"admin2",
    "email": f"admin2@telsms.com",
    "password": "Admin123!",
    "phone_number": f"09374303340"
}
response = requests.post(f"{BASE}/api/v1/auth/register/", json=register_data)
print(f"1.5 Register Repeted username User shoud be wrong: {response.status_code} - {response.json()}")


register_data = {
    "username": f"admin1",
    "email": f"admin@telsms.com",
    "password": "Admin123!",
    "phone_number": f"+989374303341"
}
response = requests.post(f"{BASE}/api/v1/auth/register/", json=register_data)
print(f"1.6 Register Repeted email User shoud be wrong: {response.status_code} - {response.json()}")
# Out:
# 1.1 Register: 201 - {'message': 'User registered successfully', 'user': {'id': 1, 'username': 'admin', 'phone_number': '+989374303340', 'email': 'admin@telsms.com', 'first_name': '', 'last_name': '', 'wallet_balance': '0.00', 'is_verified': False, 'code_verified': False, 'is_admin': False, 'is_active': True, 'default_company': 1, 'date_joined': '2025-11-19T15:54:11.406208Z', 'last_login': None}, 'api_key': 'aecb3c6bac544fd59ca663a293712fea', 'token': 'ee01c3ccc97750e39431bca5396fbcf44ec51d20'}
# 1.2 Register Repeted User shoud be wrong: 400 - {'phone_number': ['User with this phone number already exists']}
# 1.3 Register Repeted Phone User shoud be wrong: 400 - {'phone_number': ['User with this phone number already exists']}
# 1.4 Register Repeted username User shoud be wrong: 500 - {'error': 'Failed to create user'}
# ...

# %%
# 1.2: POST /api/v1/auth/login/ - Login as admin

# Login with the admin API user and capture both token and api_key
login_data = {"phone_number": "+989374303340", "password": "123"}
response = requests.post(f"{BASE}/api/v1/auth/login/", json=login_data)
login_body = response.json()
admin_token = login_body.get("token")
admin_api_key = login_body.get("api_key")
print(f"1.2 Login: {response.status_code} - Token: {admin_token}")

# Use API key for all authenticated API calls (matches backend APIKeyAuthentication)
# DRF also supports TokenAuthentication, but project HTTP tests use X-API-Key
headers = {"X-API-Key": admin_api_key}
# Out:
# 1.2 Login: 200 - Token: 2e8a32097ff0c15301b97879e8f8332833e5d62d

# %%
# 18: POST /api/v1/auth/logout/ - Logout admin user
response = requests.post(f"{BASE}/api/v1/auth/logout/", headers=headers)
print(f"18 Logout: {response.status_code} - {response.json()}")

# %%
# 1.3: GET /api/v1/auth/profile/ - Get own profile
response = requests.get(f"{BASE}/api/v1/auth/profile/", headers=headers)
print(f"1.3 Profile: {response.status_code} - {response.json()}")
# Out:
# 1.3 Profile: 200 - {'id': 3, 'username': 'admin1', 'phone_number': '+989374303341', 'email': 'admin@telsms.com', 'first_name': '', 'last_name': '', 'wallet_balance': '0.00', 'is_verified': False, 'code_verified': False, 'default_company': 3, 'active_packages_count': 0, 'date_joined': '2025-11-19T15:54:11.814564Z', 'last_login': '2025-11-19T15:54:51.105522Z'}

# %%
# 1.4: GET /api/v1/auth/wallet_info/ - Check wallet balance
response = requests.get(f"{BASE}/api/v1/auth/wallet_info/", headers=headers)
print(f"1.4 Wallet Info: {response.status_code} - {response.json()}")
# Out:
# 1.4 Wallet Info: 200 - {'balance': 0.0, 'active_packages': 0, 'can_send': False}

# %%
# 1.5: PUT /api/v1/auth/update_profile/ - Full profile update
update_data = {"phonr": "Admin", "last_name": "User"}
response = requests.put(f"{BASE}/api/v1/auth/update_profile/", json=update_data, headers=headers)
print(f"1.5 Update Profile (PUT): {response.status_code}")
print(f"{response.json()}")
# Out:
# 1.5 Update Profile (PUT): 200
# {'id': 3, 'username': 'admin1', 'phone_number': '+989374303341', 'email': 'admin@telsms.com', 'first_name': 'Admin', 'last_name': 'User', 'wallet_balance': '0.00', 'is_verified': False, 'code_verified': False, 'default_company': 3, 'active_packages_count': 0, 'date_joined': '2025-11-19T15:54:11.814564Z', 'last_login': '2025-11-19T15:54:51.105522Z'}

# %%
# 1.6: PATCH /api/v1/auth/update_profile/ - Partial profile update
patch_data = {"first_name": "Super Admin"}
response = requests.patch(f"{BASE}/api/v1/auth/update_profile/", json=patch_data, headers=headers)
print(f"1.6 Update Profile (PATCH): {response.status_code} - {response.json()}")

# %%
# 1.7: POST /api/v1/auth/change_password/ - Change password
password_data = {"old_password": "Admin123!", "new_password": "NewAdmin456!"}
response = requests.post(f"{BASE}/api/v1/auth/change_password/", json=password_data, headers=headers)
print(f"1.7 Change Password: {response.status_code} - {response.json()}")

# %%
# 1.8: POST /api/v1/auth/regenerate_api_key/ - Generate new API key
response = requests.post(f"{BASE}/api/v1/auth/regenerate_api_key/", headers=headers)
print(f"1.8 Regenerate API Key: {response.status_code} - {response.json()}")

# %%
# 1.9: GET /api/v1/auth/ - List all users (admin only)
response = requests.get(f"{BASE}/api/v1/auth/", headers=headers)
print(f"1.9 List Users: {response.status_code} - {response.json()}")
# Out:
# 1.9 List Users: 200 - {'count': 1, 'next': None, 'previous': None, 'results': [{'id': 3, 'username': 'admin1', 'phone_number': '+989374303341', 'email': 'admin@telsms.com', 'first_name': 'Admin', 'last_name': 'User', 'wallet_balance': '0.00', 'is_verified': False, 'code_verified': False, 'is_admin': False, 'is_active': True, 'default_company': 3, 'date_joined': '2025-11-19T15:54:11.814564Z', 'last_login': '2025-11-19T15:54:51.105522Z'}]}

# %%
# 1.10: POST /api/v1/auth/ - Create new user (admin only)
new_user_data = {"username": "user2", "email": "user2@test.com", "password": "Pass123!","phone_number": "+989374303344"}
response = requests.post(f"{BASE}/api/v1/auth/", json=new_user_data, headers=headers)
user_2_id = response.json().get("id")
print(f"1.10 Create User: {response.status_code} - User ID: {user_2_id}")
# Out:
# 1.10 Create User: 201 - User ID: 4

# %%
# 1.11: GET /api/v1/auth/{user_2_id}/ - Get specific user details
response = requests.get(f"{BASE}/api/v1/auth/{user_2_id}/", headers=headers)
print(f"1.11 Get User Details: {response.status_code} - {response.json()}")

# %%
# 1.12: PUT /api/v1/auth/{user_2_id}/ - Full update of user
user_update_data = {"username": "user1", "email": "updated@test.com"}
response = requests.put(f"{BASE}/api/v1/auth/{user_2_id}/", json=user_update_data, headers=headers)
print(f"1.12 Update User (PUT): {response.status_code} - {response.json()}")

# %%
# 1.13: PATCH /api/v1/auth/{user_2_id}/ - Partial update of user
user_patch_data = {"first_name": "Updated"}
response = requests.patch(f"{BASE}/api/v1/auth/{user_2_id}/", json=user_patch_data, headers=headers)
print(f"1.13 Update User (PATCH): {response.status_code} - {response.json()}")

# %%
# 1.14: DELETE /api/v1/auth/{user_2_id}/ - Delete user (admin only) - SKIPPED
print("1.14 Delete User: SKIPPED (keeping user for later tests)")

# %%
# 2.1: POST /api/v1/transactions/charge/ - Charge wallet with funds
charge_data = {"amount": 1000.00, "payment_method": "credit_card"}
response = requests.post(f"{BASE}/api/v1/transactions/charge/", json=charge_data, headers=headers)
txn_1_id = response.json().get("transaction_id")
print(f"2.1 Charge Wallet: {response.status_code} - Transaction ID: {txn_1_id}")

# %%
# 2.2: GET /api/v1/transactions/ - List all transactions
response = requests.get(f"{BASE}/api/v1/transactions/", headers=headers)
print(f"2.2 List Transactions: {response.status_code} - {response.json()}")

# %%
# 2.3: GET /api/v1/transactions/{txn_1_id}/ - Get transaction details
response = requests.get(f"{BASE}/api/v1/transactions/{txn_1_id}/", headers=headers)
print(f"2.3 Transaction Details: {response.status_code} - {response.json()}")

# %%
# 2.4: GET /api/v1/transactions/summary/ - Get transaction summary stats
response = requests.get(f"{BASE}/api/v1/transactions/summary/", headers=headers)
print(f"2.4 Transaction Summary: {response.status_code} - {response.json()}")

# %%
# 2.5: GET /api/v1/transactions/balance_history/ - View balance history over time
response = requests.get(f"{BASE}/api/v1/transactions/balance_history/", headers=headers)
print(f"2.5 Balance History: {response.status_code} - {response.json()}")

# %%
# 2.6: GET /api/v1/transactions/pending/ - Get pending transactions
response = requests.get(f"{BASE}/api/v1/transactions/pending/", headers=headers)
print(f"2.6 Pending Transactions: {response.status_code} - {response.json()}")

# %%
# 2.7: POST /api/v1/transactions/purchase_package/ - Purchase package via transaction
purchase_data = {"package_id": 1}
response = requests.post(f"{BASE}/api/v1/transactions/purchase_package/", json=purchase_data, headers=headers)
result = response.json()
txn_2_id = result.get("transaction_id")
sub_1_id = result.get("subscription_id")
print(f"2.7 Purchase Package: {response.status_code} - Transaction ID: {txn_2_id}, Subscription ID: {sub_1_id}")

# %%
# 2.8: POST /api/v1/transactions/{txn_1_id}/refund/ - Refund transaction (admin only)
refund_data = {"reason": "Test refund"}
response = requests.post(f"{BASE}/api/v1/transactions/{txn_1_id}/refund/", json=refund_data, headers=headers)
print(f"2.8 Refund Transaction: {response.status_code} - {response.json()}")

# %%
# 3.1: GET /api/v1/packages/packages/ - List all available packages
response = requests.get(f"{BASE}/api/v1/packages/packages/", headers=headers)
packages = response.json().get("results", [])
pkg_1_id = packages[0]["id"] if len(packages) > 0 else 1
pkg_2_id = packages[1]["id"] if len(packages) > 1 else 2
pkg_3_id = packages[2]["id"] if len(packages) > 2 else 3
print(f"3.1 List Packages: {response.status_code} - Package IDs: {pkg_1_id}, {pkg_2_id}, {pkg_3_id}")

# %%
# 3.2: GET /api/v1/packages/packages/{pkg_2_id}/ - Get specific package details
response = requests.get(f"{BASE}/api/v1/packages/packages/{pkg_2_id}/", headers=headers)
print(f"3.2 Package Details: {response.status_code} - {response.json()}")

# %%
# 3.3: POST /api/v1/packages/subscriptions/subscribe/ - Subscribe to a package
subscribe_data = {"package_id": pkg_2_id}
response = requests.post(f"{BASE}/api/v1/packages/subscriptions/subscribe/", json=subscribe_data, headers=headers)
sub_2_id = response.json().get("subscription_id")
print(f"3.3 Subscribe: {response.status_code} - Subscription ID: {sub_2_id}")

# %%
# 3.4: POST /api/v1/packages/subscriptions/purchase/ - Alternative purchase method
purchase_data = {"package_id": pkg_3_id, "payment_method": "wallet"}
response = requests.post(f"{BASE}/api/v1/packages/subscriptions/purchase/", json=purchase_data, headers=headers)
sub_3_id = response.json().get("subscription_id")
print(f"3.4 Purchase Subscription: {response.status_code} - Subscription ID: {sub_3_id}")

# %%
# 3.5: GET /api/v1/packages/subscriptions/ - List all subscriptions
response = requests.get(f"{BASE}/api/v1/packages/subscriptions/", headers=headers)
print(f"3.5 List Subscriptions: {response.status_code} - {response.json()}")

# %%
# 3.6: POST /api/v1/packages/subscriptions/ - Create subscription (admin only)
create_sub_data = {"user_id": user_2_id, "package_id": pkg_1_id}
response = requests.post(f"{BASE}/api/v1/packages/subscriptions/", json=create_sub_data, headers=headers)
sub_4_id = response.json().get("id")
print(f"3.6 Create Subscription: {response.status_code} - Subscription ID: {sub_4_id}")

# %%
# 3.7: GET /api/v1/packages/subscriptions/{sub_1_id}/ - Get subscription details
response = requests.get(f"{BASE}/api/v1/packages/subscriptions/{sub_1_id}/", headers=headers)
print(f"3.7 Subscription Details: {response.status_code} - {response.json()}")

# %%
# 3.8: PUT /api/v1/packages/subscriptions/{sub_1_id}/ - Full update subscription
update_sub_data = {"auto_renew": True}
response = requests.put(f"{BASE}/api/v1/packages/subscriptions/{sub_1_id}/", json=update_sub_data, headers=headers)
print(f"3.8 Update Subscription (PUT): {response.status_code} - {response.json()}")

# %%
# 3.9: PATCH /api/v1/packages/subscriptions/{sub_1_id}/ - Partial update subscription
patch_sub_data = {"notes": "Updated notes"}
response = requests.patch(f"{BASE}/api/v1/packages/subscriptions/{sub_1_id}/", json=patch_sub_data, headers=headers)
print(f"3.9 Update Subscription (PATCH): {response.status_code} - {response.json()}")

# %%
# 3.10: DELETE /api/v1/packages/subscriptions/{sub_4_id}/ - Delete subscription
response = requests.delete(f"{BASE}/api/v1/packages/subscriptions/{sub_4_id}/", headers=headers)
print(f"3.10 Delete Subscription: {response.status_code} - {response.json()}")

# %%
# 3.11: POST /api/v1/packages/subscriptions/{sub_1_id}/renew/ - Renew subscription
response = requests.post(f"{BASE}/api/v1/packages/subscriptions/{sub_1_id}/renew/", headers=headers)
print(f"3.11 Renew Subscription: {response.status_code} - {response.json()}")

# %%
# 3.12: GET /api/v1/packages/subscriptions/{sub_1_id}/usage/ - Get subscription usage stats
response = requests.get(f"{BASE}/api/v1/packages/subscriptions/{sub_1_id}/usage/", headers=headers)
print(f"3.12 Subscription Usage: {response.status_code} - {response.json()}")

# %%
# 3.13: GET /api/v1/packages/subscriptions/active/ - Get all active subscriptions
response = requests.get(f"{BASE}/api/v1/packages/subscriptions/active/", headers=headers)
print(f"3.13 Active Subscriptions: {response.status_code} - {response.json()}")

# %%
# 3.14: GET /api/v1/packages/usage/ - List all usage records
response = requests.get(f"{BASE}/api/v1/packages/usage/", headers=headers)
print(f"3.14 List Usage Records: {response.status_code} - {response.json()}")

# %%
# 3.15: GET /api/v1/packages/usage/{usage_1_id}/ - Get specific usage record details
usage_1_id = 1  # Assuming usage record exists
response = requests.get(f"{BASE}/api/v1/packages/usage/{usage_1_id}/", headers=headers)
print(f"3.15 Usage Record Details: {response.status_code} - {response.json()}")

# %%
# 3.16: GET /api/v1/packages/usage/by_date_range/ - Usage by date range
params = {"start_date": "2024-01-01", "end_date": "2024-12-31"}
response = requests.get(f"{BASE}/api/v1/packages/usage/by_date_range/", params=params, headers=headers)
print(f"3.16 Usage by Date Range: {response.status_code} - {response.json()}")

# %%
# 3.17: GET /api/v1/packages/usage/summary/ - Get usage summary
response = requests.get(f"{BASE}/api/v1/packages/usage/summary/", headers=headers)
print(f"3.17 Usage Summary: {response.status_code} - {response.json()}")

# %%
# 3.18: GET /api/v1/packages/usage/today/ - Get today's usage
response = requests.get(f"{BASE}/api/v1/packages/usage/today/", headers=headers)
print(f"3.18 Today's Usage: {response.status_code} - {response.json()}")

# %%
# 4.1: GET /api/v1/accounts/telegram/ - List all Telegram accounts
response = requests.get(f"{BASE}/api/v1/accounts/telegram/", headers=headers)
print(f"4.1 List Telegram Accounts: {response.status_code} - {response.json()}")

# %%
# 4.2: POST /api/v1/accounts/telegram/ - Create Telegram account
tg_account_data = {"phone_number": "+1234567890", "account_name": "Admin TG"}
response = requests.post(f"{BASE}/api/v1/accounts/telegram/", json=tg_account_data, headers=headers)
tg_acc_1_id = response.json().get("id")
print(f"4.2 Create Telegram Account: {response.status_code} - Account ID: {tg_acc_1_id}")

# %%
# 4.3: POST /api/v1/accounts/telegram-login/send-code/ - Send verification code to phone
send_code_data = {"phone_number": "+1234567890"}
response = requests.post(f"{BASE}/api/v1/accounts/telegram-login/send-code/", json=send_code_data, headers=headers)
phone_code_hash = response.json().get("phone_code_hash")
print(f"4.3 Send Code: {response.status_code} - Hash: {phone_code_hash}")

# %%
# 4.4: POST /api/v1/accounts/telegram-login/verify-code/ - Verify code received
verify_code_data = {"phone_number": "+1234567890", "code": "12345", "phone_code_hash": phone_code_hash}
response = requests.post(f"{BASE}/api/v1/accounts/telegram-login/verify-code/", json=verify_code_data, headers=headers)
print(f"4.4 Verify Code: {response.status_code} - {response.json()}")

# %%
# 4.5: POST /api/v1/accounts/telegram-login/verify-password/ - Verify 2FA password if enabled
verify_password_data = {"phone_number": "+1234567890", "password": "tg_password"}
response = requests.post(f"{BASE}/api/v1/accounts/telegram-login/verify-password/", json=verify_password_data, headers=headers)
print(f"4.5 Verify Password: {response.status_code} - {response.json()}")

# %%
# 4.6: POST /api/v1/accounts/telegram-login/start-polling/ - Start polling for updates
start_polling_data = {"account_id": tg_acc_1_id}
response = requests.post(f"{BASE}/api/v1/accounts/telegram-login/start-polling/", json=start_polling_data, headers=headers)
print(f"4.6 Start Polling: {response.status_code} - {response.json()}")

# %%
# 4.7: GET /api/v1/accounts/telegram/{tg_acc_1_id}/ - Get Telegram account details
response = requests.get(f"{BASE}/api/v1/accounts/telegram/{tg_acc_1_id}/", headers=headers)
print(f"4.7 Telegram Account Details: {response.status_code} - {response.json()}")

# %%
# 4.8: PUT /api/v1/accounts/telegram/{tg_acc_1_id}/ - Full update Telegram account
update_tg_data = {"account_name": "Updated Admin TG", "is_active": True}
response = requests.put(f"{BASE}/api/v1/accounts/telegram/{tg_acc_1_id}/", json=update_tg_data, headers=headers)
print(f"4.8 Update Telegram Account (PUT): {response.status_code} - {response.json()}")

# %%
# 4.9: PATCH /api/v1/accounts/telegram/{tg_acc_1_id}/ - Partial update Telegram account
patch_tg_data = {"is_active": False}
response = requests.patch(f"{BASE}/api/v1/accounts/telegram/{tg_acc_1_id}/", json=patch_tg_data, headers=headers)
print(f"4.9 Update Telegram Account (PATCH): {response.status_code} - {response.json()}")

# %%
# 4.10: DELETE /api/v1/accounts/telegram/{tg_acc_1_id}/ - Delete Telegram account
response = requests.delete(f"{BASE}/api/v1/accounts/telegram/{tg_acc_1_id}/", headers=headers)
print(f"4.10 Delete Telegram Account: {response.status_code} - {response.json()}")

# %%
# 5.1: GET /api/v1/accounts/instagram/ - List all Instagram accounts
response = requests.get(f"{BASE}/api/v1/accounts/instagram/", headers=headers)
print(f"5.1 List Instagram Accounts: {response.status_code} - {response.json()}")

# %%
# 5.2: POST /api/v1/accounts/instagram/ - Create Instagram account
ig_account_data = {"username": "admin_insta", "password": "InstaPass123!"}
response = requests.post(f"{BASE}/api/v1/accounts/instagram/", json=ig_account_data, headers=headers)
ig_acc_1_id = response.json().get("id")
print(f"5.2 Create Instagram Account: {response.status_code} - Account ID: {ig_acc_1_id}")

# %%
# 5.3: GET /api/v1/accounts/instagram/{ig_acc_1_id}/ - Get Instagram account details
response = requests.get(f"{BASE}/api/v1/accounts/instagram/{ig_acc_1_id}/", headers=headers)
print(f"5.3 Instagram Account Details: {response.status_code} - {response.json()}")

# %%
# 5.4: PUT /api/v1/accounts/instagram/{ig_acc_1_id}/ - Full update Instagram account
update_ig_data = {"username": "admin_insta", "is_active": True}
response = requests.put(f"{BASE}/api/v1/accounts/instagram/{ig_acc_1_id}/", json=update_ig_data, headers=headers)
print(f"5.4 Update Instagram Account (PUT): {response.status_code} - {response.json()}")

# %%
# 5.5: PATCH /api/v1/accounts/instagram/{ig_acc_1_id}/ - Partial update Instagram account
patch_ig_data = {"is_active": False}
response = requests.patch(f"{BASE}/api/v1/accounts/instagram/{ig_acc_1_id}/", json=patch_ig_data, headers=headers)
print(f"5.5 Update Instagram Account (PATCH): {response.status_code} - {response.json()}")

# %%
# 5.6: DELETE /api/v1/accounts/instagram/{ig_acc_1_id}/ - Delete Instagram account
response = requests.delete(f"{BASE}/api/v1/accounts/instagram/{ig_acc_1_id}/", headers=headers)
print(f"5.6 Delete Instagram Account: {response.status_code} - {response.json()}")

# %%
# 6.1: GET /api/v1/accounts/twilio/ - List all Twilio accounts
response = requests.get(f"{BASE}/api/v1/accounts/twilio/", headers=headers)
print(f"6.1 List Twilio Accounts: {response.status_code} - {response.json()}")

# %%
# 6.2: POST /api/v1/accounts/twilio/ - Create Twilio account
twilio_account_data = {"account_sid": "ACxxxx", "auth_token": "token123", "phone_number": "+1987654321"}
response = requests.post(f"{BASE}/api/v1/accounts/twilio/", json=twilio_account_data, headers=headers)
twilio_acc_1_id = response.json().get("id")
print(f"6.2 Create Twilio Account: {response.status_code} - Account ID: {twilio_acc_1_id}")

# %%
# 6.3: GET /api/v1/accounts/twilio/{twilio_acc_1_id}/ - Get Twilio account details
response = requests.get(f"{BASE}/api/v1/accounts/twilio/{twilio_acc_1_id}/", headers=headers)
print(f"6.3 Twilio Account Details: {response.status_code} - {response.json()}")

# %%
# 6.4: PUT /api/v1/accounts/twilio/{twilio_acc_1_id}/ - Full update Twilio account
update_twilio_data = {"account_sid": "ACxxxx", "auth_token": "new_token456"}
response = requests.put(f"{BASE}/api/v1/accounts/twilio/{twilio_acc_1_id}/", json=update_twilio_data, headers=headers)
print(f"6.4 Update Twilio Account (PUT): {response.status_code} - {response.json()}")

# %%
# 6.5: PATCH /api/v1/accounts/twilio/{twilio_acc_1_id}/ - Partial update Twilio account
patch_twilio_data = {"is_active": True}
response = requests.patch(f"{BASE}/api/v1/accounts/twilio/{twilio_acc_1_id}/", json=patch_twilio_data, headers=headers)
print(f"6.5 Update Twilio Account (PATCH): {response.status_code} - {response.json()}")

# %%
# 6.6: DELETE /api/v1/accounts/twilio/{twilio_acc_1_id}/ - Delete Twilio account
response = requests.delete(f"{BASE}/api/v1/accounts/twilio/{twilio_acc_1_id}/", headers=headers)
print(f"6.6 Delete Twilio Account: {response.status_code} - {response.json()}")

# %%
# 7.1: GET /api/v1/accounts/whatsapp/ - List all WhatsApp accounts
response = requests.get(f"{BASE}/api/v1/accounts/whatsapp/", headers=headers)
print(f"7.1 List WhatsApp Accounts: {response.status_code} - {response.json()}")

# %%
# 7.2: POST /api/v1/accounts/whatsapp/ - Create WhatsApp account
wa_account_data = {"phone_number": "+1555555555", "api_key": "wa_key_xyz"}
response = requests.post(f"{BASE}/api/v1/accounts/whatsapp/", json=wa_account_data, headers=headers)
wa_acc_1_id = response.json().get("id")
print(f"7.2 Create WhatsApp Account: {response.status_code} - Account ID: {wa_acc_1_id}")

# %%
# 7.3: GET /api/v1/accounts/whatsapp/{wa_acc_1_id}/ - Get WhatsApp account details
response = requests.get(f"{BASE}/api/v1/accounts/whatsapp/{wa_acc_1_id}/", headers=headers)
print(f"7.3 WhatsApp Account Details: {response.status_code} - {response.json()}")

# %%
# 7.4: PUT /api/v1/accounts/whatsapp/{wa_acc_1_id}/ - Full update WhatsApp account
update_wa_data = {"phone_number": "+1555555555", "api_key": "new_wa_key_abc"}
response = requests.put(f"{BASE}/api/v1/accounts/whatsapp/{wa_acc_1_id}/", json=update_wa_data, headers=headers)
print(f"7.4 Update WhatsApp Account (PUT): {response.status_code} - {response.json()}")

# %%
# 7.5: PATCH /api/v1/accounts/whatsapp/{wa_acc_1_id}/ - Partial update WhatsApp account
patch_wa_data = {"is_active": True}
response = requests.patch(f"{BASE}/api/v1/accounts/whatsapp/{wa_acc_1_id}/", json=patch_wa_data, headers=headers)
print(f"7.5 Update WhatsApp Account (PATCH): {response.status_code} - {response.json()}")

# %%
# 7.6: DELETE /api/v1/accounts/whatsapp/{wa_acc_1_id}/ - Delete WhatsApp account
response = requests.delete(f"{BASE}/api/v1/accounts/whatsapp/{wa_acc_1_id}/", headers=headers)
print(f"7.6 Delete WhatsApp Account: {response.status_code} - {response.json()}")

# %%
# 8.1: GET /api/v1/accounts/platform-accounts/ - List all platform accounts
response = requests.get(f"{BASE}/api/v1/accounts/platform-accounts/", headers=headers)
print(f"8.1 List Platform Accounts: {response.status_code} - {response.json()}")

# %%
# 8.2: POST /api/v1/accounts/platform-accounts/ - Create generic platform account
platform_account_data = {"platform": "telegram", "credentials": {"phone": "+1234567890"}}
response = requests.post(f"{BASE}/api/v1/accounts/platform-accounts/", json=platform_account_data, headers=headers)
platform_acc_5_id = response.json().get("id")
print(f"8.2 Create Platform Account: {response.status_code} - Account ID: {platform_acc_5_id}")

# %%
# 8.3: GET /api/v1/accounts/platform-accounts/{platform_acc_5_id}/ - Get platform account details
response = requests.get(f"{BASE}/api/v1/accounts/platform-accounts/{platform_acc_5_id}/", headers=headers)
print(f"8.3 Platform Account Details: {response.status_code} - {response.json()}")

# %%
# 8.4: PUT /api/v1/accounts/platform-accounts/{platform_acc_5_id}/ - Full update platform account
update_platform_data = {"is_active": True, "nickname": "Primary"}
response = requests.put(f"{BASE}/api/v1/accounts/platform-accounts/{platform_acc_5_id}/", json=update_platform_data, headers=headers)
print(f"8.4 Update Platform Account (PUT): {response.status_code} - {response.json()}")

# %%
# 8.5: PATCH /api/v1/accounts/platform-accounts/{platform_acc_5_id}/ - Partial update platform account
patch_platform_data = {"nickname": "Primary Account"}
response = requests.patch(f"{BASE}/api/v1/accounts/platform-accounts/{platform_acc_5_id}/", json=patch_platform_data, headers=headers)
print(f"8.5 Update Platform Account (PATCH): {response.status_code} - {response.json()}")

# %%
# 8.6: DELETE /api/v1/accounts/platform-accounts/{platform_acc_5_id}/ - Delete platform account
response = requests.delete(f"{BASE}/api/v1/accounts/platform-accounts/{platform_acc_5_id}/", headers=headers)
print(f"8.6 Delete Platform Account: {response.status_code} - {response.json()}")

# %%
# 8.7: POST /api/v1/accounts/platform-accounts/{platform_acc_5_id}/activate/ - Activate account
response = requests.post(f"{BASE}/api/v1/accounts/platform-accounts/{platform_acc_5_id}/activate/", headers=headers)
print(f"8.7 Activate Account: {response.status_code} - {response.json()}")

# %%
# 8.8: POST /api/v1/accounts/platform-accounts/{platform_acc_5_id}/deactivate/ - Deactivate account
response = requests.post(f"{BASE}/api/v1/accounts/platform-accounts/{platform_acc_5_id}/deactivate/", headers=headers)
print(f"8.8 Deactivate Account: {response.status_code} - {response.json()}")

# %%
# 8.9: GET /api/v1/accounts/platform-accounts/by_platform/ - Filter accounts by platform
params = {"platform": "telegram"}
response = requests.get(f"{BASE}/api/v1/accounts/platform-accounts/by_platform/", params=params, headers=headers)
print(f"8.9 Filter by Platform: {response.status_code} - {response.json()}")

# %%
# 8.10: GET /api/v1/accounts/platform-accounts/stats/ - Get platform account statistics
response = requests.get(f"{BASE}/api/v1/accounts/platform-accounts/stats/", headers=headers)
print(f"8.10 Platform Account Stats: {response.status_code} - {response.json()}")

# %%
# 9.1: GET /api/v1/companies/ - List all companies
response = requests.get(f"{BASE}/api/v1/companies/", headers=headers)
print(f"9.1 List Companies: {response.status_code} - {response.json()}")

# %%
# 9.2: POST /api/v1/companies/ - Create company
company_data = {"name": "Test Company", "description": "A test company"}
response = requests.post(f"{BASE}/api/v1/companies/", json=company_data, headers=headers)
result = response.json()
company_1_id = result.get("id")
invite_code = result.get("invite_code")
print(f"9.2 Create Company: {response.status_code} - Company ID: {company_1_id}, Invite Code: {invite_code}")

# %%
# 9.3: GET /api/v1/companies/{company_1_id}/ - Get company details
response = requests.get(f"{BASE}/api/v1/companies/{company_1_id}/", headers=headers)
print(f"9.3 Company Details: {response.status_code} - {response.json()}")

# %%
# 9.4: PUT /api/v1/companies/{company_1_id}/ - Full update company
update_company_data = {"name": "Updated Test Company", "description": "Updated desc"}
response = requests.put(f"{BASE}/api/v1/companies/{company_1_id}/", json=update_company_data, headers=headers)
print(f"9.4 Update Company (PUT): {response.status_code} - {response.json()}")

# %%
# 9.5: PATCH /api/v1/companies/{company_1_id}/ - Partial update company
patch_company_data = {"description": "Partially updated"}
response = requests.patch(f"{BASE}/api/v1/companies/{company_1_id}/", json=patch_company_data, headers=headers)
print(f"9.5 Update Company (PATCH): {response.status_code} - {response.json()}")

# %%
# 9.6: DELETE /api/v1/companies/{company_1_id}/ - Delete company - SKIPPED
print("9.6 Delete Company: SKIPPED (keeping for membership tests)")

# %%
# 9.7: POST /api/v1/companies/{company_1_id}/regenerate_invite/ - Regenerate invite code
response = requests.post(f"{BASE}/api/v1/companies/{company_1_id}/regenerate_invite/", headers=headers)
invite_code = response.json().get("invite_code")
print(f"9.7 Regenerate Invite: {response.status_code} - New Invite Code: {invite_code}")

# %%
# 9.8: POST /api/v1/companies/join_by_invite/ - Join company using invite code
join_data = {"invite_code": invite_code}
response = requests.post(f"{BASE}/api/v1/companies/join_by_invite/", json=join_data, headers=headers)
membership_1_id = response.json().get("membership_id")
print(f"9.8 Join by Invite: {response.status_code} - Membership ID: {membership_1_id}")

# %%
# 9.9: GET /api/v1/companies/memberships/ - List all memberships
response = requests.get(f"{BASE}/api/v1/companies/memberships/", headers=headers)
print(f"9.9 List Memberships: {response.status_code} - {response.json()}")

# %%
# 9.10: POST /api/v1/companies/memberships/ - Create membership (admin only)
membership_data = {"company_id": company_1_id, "user_id": user_2_id, "role": "member"}
response = requests.post(f"{BASE}/api/v1/companies/memberships/", json=membership_data, headers=headers)
membership_2_id = response.json().get("id")
print(f"9.10 Create Membership: {response.status_code} - Membership ID: {membership_2_id}")

# %%
# 9.11: GET /api/v1/companies/memberships/{membership_1_id}/ - Get membership details
response = requests.get(f"{BASE}/api/v1/companies/memberships/{membership_1_id}/", headers=headers)
print(f"9.11 Membership Details: {response.status_code} - {response.json()}")

# %%
# 9.12: PUT /api/v1/companies/memberships/{membership_1_id}/ - Full update membership
update_membership_data = {"role": "manager", "status": "active"}
response = requests.put(f"{BASE}/api/v1/companies/memberships/{membership_1_id}/", json=update_membership_data, headers=headers)
print(f"9.12 Update Membership (PUT): {response.status_code} - {response.json()}")

# %%
# 9.13: PATCH /api/v1/companies/memberships/{membership_1_id}/ - Partial update membership
patch_membership_data = {"status": "active"}
response = requests.patch(f"{BASE}/api/v1/companies/memberships/{membership_1_id}/", json=patch_membership_data, headers=headers)
print(f"9.13 Update Membership (PATCH): {response.status_code} - {response.json()}")

# %%
# 9.14: DELETE /api/v1/companies/memberships/{membership_2_id}/ - Delete membership
response = requests.delete(f"{BASE}/api/v1/companies/memberships/{membership_2_id}/", headers=headers)
print(f"9.14 Delete Membership: {response.status_code} - {response.json()}")

# %%
# 9.15: POST /api/v1/companies/memberships/{membership_1_id}/approve_reject/ - Approve or reject membership
approve_data = {"action": "approve"}
response = requests.post(f"{BASE}/api/v1/companies/memberships/{membership_1_id}/approve_reject/", json=approve_data, headers=headers)
print(f"9.15 Approve Membership: {response.status_code} - {response.json()}")

# %%
# 10.1: GET /api/v1/messages/templates/ - List all message templates
response = requests.get(f"{BASE}/api/v1/messages/templates/", headers=headers)
print(f"10.1 List Templates: {response.status_code} - {response.json()}")

# %%
# 10.2: POST /api/v1/messages/templates/ - Create message template
template_data = {"name": "Welcome", "content": "Hello {{name}}!", "platform": "telegram"}
response = requests.post(f"{BASE}/api/v1/messages/templates/", json=template_data, headers=headers)
template_1_id = response.json().get("id")
print(f"10.2 Create Template: {response.status_code} - Template ID: {template_1_id}")

# %%
# 10.3: GET /api/v1/messages/templates/{template_1_id}/ - Get template details
response = requests.get(f"{BASE}/api/v1/messages/templates/{template_1_id}/", headers=headers)
print(f"10.3 Template Details: {response.status_code} - {response.json()}")

# %%
# 10.4: PUT /api/v1/messages/templates/{template_1_id}/ - Full update template
update_template_data = {"name": "Welcome Updated", "content": "Hi {{name}}!", "platform": "telegram"}
response = requests.put(f"{BASE}/api/v1/messages/templates/{template_1_id}/", json=update_template_data, headers=headers)
print(f"10.4 Update Template (PUT): {response.status_code} - {response.json()}")

# %%
# 10.5: PATCH /api/v1/messages/templates/{template_1_id}/ - Partial update template
patch_template_data = {"content": "Hey {{name}}!"}
response = requests.patch(f"{BASE}/api/v1/messages/templates/{template_1_id}/", json=patch_template_data, headers=headers)
print(f"10.5 Update Template (PATCH): {response.status_code} - {response.json()}")

# %%
# 10.6: DELETE /api/v1/messages/templates/{template_1_id}/ - Delete template - SKIPPED
print("10.6 Delete Template: SKIPPED (keeping for tests)")

# %%
# 10.7: POST /api/v1/messages/templates/{template_1_id}/activate/ - Activate template
response = requests.post(f"{BASE}/api/v1/messages/templates/{template_1_id}/activate/", headers=headers)
print(f"10.7 Activate Template: {response.status_code} - {response.json()}")

# %%
# 10.8: POST /api/v1/messages/templates/{template_1_id}/deactivate/ - Deactivate template
response = requests.post(f"{BASE}/api/v1/messages/templates/{template_1_id}/deactivate/", headers=headers)
print(f"10.8 Deactivate Template: {response.status_code} - {response.json()}")

# %%
# 10.9: GET /api/v1/messages/templates/{template_1_id}/preview/ - Preview template rendering
response = requests.get(f"{BASE}/api/v1/messages/templates/{template_1_id}/preview/", headers=headers)
print(f"10.9 Template Preview: {response.status_code} - {response.json()}")

# %%
# 10.10: POST /api/v1/messages/templates/{template_1_id}/render/ - Render template with variables
render_data = {"variables": {"name": "Admin"}}
response = requests.post(f"{BASE}/api/v1/messages/templates/{template_1_id}/render/", json=render_data, headers=headers)
print(f"10.10 Render Template: {response.status_code} - {response.json()}")

# %%
# 11.1: POST /api/v1/messages/send/telegram/send/ - Send Telegram message
tg_send_data = {"account_id": 1, "recipient": "@username", "message": "Hello via Telegram"}
response = requests.post(f"{BASE}/api/v1/messages/send/telegram/send/", json=tg_send_data, headers=headers)
msg_1_id = response.json().get("message_id")
print(f"11.1 Send Telegram: {response.status_code} - Message ID: {msg_1_id}")

# %%
# 11.2: POST /api/v1/messages/send/instagram/send/ - Send Instagram message
ig_send_data = {"account_id": 1, "recipient": "instagram_user", "message": "Hello via Instagram"}
response = requests.post(f"{BASE}/api/v1/messages/send/instagram/send/", json=ig_send_data, headers=headers)
msg_2_id = response.json().get("message_id")
print(f"11.2 Send Instagram: {response.status_code} - Message ID: {msg_2_id}")

# %%
# 11.3: POST /api/v1/messages/send/sms/send/ - Send SMS message
sms_send_data = {"account_id": 1, "recipient": "+1234567890", "message": "Hello via SMS"}
response = requests.post(f"{BASE}/api/v1/messages/send/sms/send/", json=sms_send_data, headers=headers)
msg_3_id = response.json().get("message_id")
print(f"11.3 Send SMS: {response.status_code} - Message ID: {msg_3_id}")

# %%
# 11.4: POST /api/v1/messages/send/whatsapp/send/ - Send WhatsApp message
wa_send_data = {"account_id": 1, "recipient": "+1234567890", "message": "Hello via WhatsApp"}
response = requests.post(f"{BASE}/api/v1/messages/send/whatsapp/send/", json=wa_send_data, headers=headers)
msg_4_id = response.json().get("message_id")
print(f"11.4 Send WhatsApp: {response.status_code} - Message ID: {msg_4_id}")

# %%
# 11.5: POST /api/v1/messages/messages/send/ - Generic send message endpoint
generic_send_data = {"platform": "telegram", "account_id": 1, "recipient": "@user", "content": "Generic send"}
response = requests.post(f"{BASE}/api/v1/messages/messages/send/", json=generic_send_data, headers=headers)
msg_5_id = response.json().get("message_id")
print(f"11.5 Generic Send: {response.status_code} - Message ID: {msg_5_id}")

# %%
# 11.6: GET /api/v1/messages/send/{msg_1_id}/status/ - Check message send status
response = requests.get(f"{BASE}/api/v1/messages/send/{msg_1_id}/status/", headers=headers)
print(f"11.6 Message Status: {response.status_code} - {response.json()}")

# %%
# 11.7: GET /api/v1/messages/send/history/ - Get send history
response = requests.get(f"{BASE}/api/v1/messages/send/history/", headers=headers)
print(f"11.7 Send History: {response.status_code} - {response.json()}")

# %%
# 12.1: GET /api/v1/messages/messages/ - List all messages
response = requests.get(f"{BASE}/api/v1/messages/messages/", headers=headers)
print(f"12.1 List Messages: {response.status_code} - {response.json()}")

# %%
# 12.2: POST /api/v1/messages/messages/ - Create message record
message_data = {"platform": "telegram", "content": "Test message", "recipient": "@user"}
response = requests.post(f"{BASE}/api/v1/messages/messages/", json=message_data, headers=headers)
msg_6_id = response.json().get("id")
print(f"12.2 Create Message: {response.status_code} - Message ID: {msg_6_id}")

# %%
# 12.3: GET /api/v1/messages/messages/{msg_1_id}/ - Get message details
response = requests.get(f"{BASE}/api/v1/messages/messages/{msg_1_id}/", headers=headers)
print(f"12.3 Message Details: {response.status_code} - {response.json()}")

# %%
# 12.4: PUT /api/v1/messages/messages/{msg_6_id}/ - Full update message
update_message_data = {"content": "Updated test message", "status": "pending"}
response = requests.put(f"{BASE}/api/v1/messages/messages/{msg_6_id}/", json=update_message_data, headers=headers)
print(f"12.4 Update Message (PUT): {response.status_code} - {response.json()}")

# %%
# 12.5: PATCH /api/v1/messages/messages/{msg_6_id}/ - Partial update message
patch_message_data = {"status": "sent"}
response = requests.patch(f"{BASE}/api/v1/messages/messages/{msg_6_id}/", json=patch_message_data, headers=headers)
print(f"12.5 Update Message (PATCH): {response.status_code} - {response.json()}")

# %%
# 12.6: DELETE /api/v1/messages/messages/{msg_6_id}/ - Delete message
response = requests.delete(f"{BASE}/api/v1/messages/messages/{msg_6_id}/", headers=headers)
print(f"12.6 Delete Message: {response.status_code} - {response.json()}")

# %%
# 12.7: POST /api/v1/messages/messages/{msg_1_id}/mark_sent/ - Mark message as sent
response = requests.post(f"{BASE}/api/v1/messages/messages/{msg_1_id}/mark_sent/", headers=headers)
print(f"12.7 Mark as Sent: {response.status_code} - {response.json()}")

# %%
# 12.8: POST /api/v1/messages/messages/{msg_2_id}/mark_failed/ - Mark message as failed
mark_failed_data = {"reason": "Delivery failed"}
response = requests.post(f"{BASE}/api/v1/messages/messages/{msg_2_id}/mark_failed/", json=mark_failed_data, headers=headers)
print(f"12.8 Mark as Failed: {response.status_code} - {response.json()}")

# %%
# 12.9: GET /api/v1/messages/messages/statistics/ - Get message statistics
response = requests.get(f"{BASE}/api/v1/messages/messages/statistics/", headers=headers)
print(f"12.9 Message Statistics: {response.status_code} - {response.json()}")

# %%
# 13.1: GET /api/v1/messages/conversations/ - List all conversations
response = requests.get(f"{BASE}/api/v1/messages/conversations/", headers=headers)
print(f"13.1 List Conversations: {response.status_code} - {response.json()}")

# %%
# 13.2: POST /api/v1/messages/conversations/ - Create conversation
conversation_data = {"platform": "telegram", "participant": "@user", "subject": "Support"}
response = requests.post(f"{BASE}/api/v1/messages/conversations/", json=conversation_data, headers=headers)
conv_1_id = response.json().get("id")
print(f"13.2 Create Conversation: {response.status_code} - Conversation ID: {conv_1_id}")

# %%
# 13.3: GET /api/v1/messages/conversations/{conv_1_id}/ - Get conversation details
response = requests.get(f"{BASE}/api/v1/messages/conversations/{conv_1_id}/", headers=headers)
print(f"13.3 Conversation Details: {response.status_code} - {response.json()}")

# %%
# 13.4: PUT /api/v1/messages/conversations/{conv_1_id}/ - Full update conversation
update_conv_data = {"subject": "Updated Support", "notes": "Customer inquiry"}
response = requests.put(f"{BASE}/api/v1/messages/conversations/{conv_1_id}/", json=update_conv_data, headers=headers)
print(f"13.4 Update Conversation (PUT): {response.status_code} - {response.json()}")

# %%
# 13.5: PATCH /api/v1/messages/conversations/{conv_1_id}/ - Partial update conversation
patch_conv_data = {"notes": "Resolved"}
response = requests.patch(f"{BASE}/api/v1/messages/conversations/{conv_1_id}/", json=patch_conv_data, headers=headers)
print(f"13.5 Update Conversation (PATCH): {response.status_code} - {response.json()}")

# %%
# 13.6: DELETE /api/v1/messages/conversations/{conv_1_id}/ - Delete conversation - SKIPPED
print("13.6 Delete Conversation: SKIPPED (keeping for further tests)")

# %%
# 13.7: POST /api/v1/messages/conversations/{conv_1_id}/mark_read/ - Mark conversation as read
response = requests.post(f"{BASE}/api/v1/messages/conversations/{conv_1_id}/mark_read/", headers=headers)
print(f"13.7 Mark as Read: {response.status_code} - {response.json()}")

# %%
# 13.8: POST /api/v1/messages/conversations/{conv_1_id}/archive/ - Archive conversation
response = requests.post(f"{BASE}/api/v1/messages/conversations/{conv_1_id}/archive/", headers=headers)
print(f"13.8 Archive Conversation: {response.status_code} - {response.json()}")

# %%
# 13.9: POST /api/v1/messages/conversations/{conv_1_id}/unarchive/ - Unarchive conversation
response = requests.post(f"{BASE}/api/v1/messages/conversations/{conv_1_id}/unarchive/", headers=headers)
print(f"13.9 Unarchive Conversation: {response.status_code} - {response.json()}")

# %%
# 13.10: POST /api/v1/messages/conversations/bulk_mark_read/ - Bulk mark multiple as read
bulk_read_data = {"conversation_ids": [conv_1_id]}
response = requests.post(f"{BASE}/api/v1/messages/conversations/bulk_mark_read/", json=bulk_read_data, headers=headers)
print(f"13.10 Bulk Mark as Read: {response.status_code} - {response.json()}")

# %%
# 14.1: GET /api/v1/notifications/ - List all notifications
response = requests.get(f"{BASE}/api/v1/notifications/", headers=headers)
print(f"14.1 List Notifications: {response.status_code} - {response.json()}")

# %%
# 14.2: GET /api/v1/notifications/unread/ - Get unread notifications only
response = requests.get(f"{BASE}/api/v1/notifications/unread/", headers=headers)
print(f"14.2 Unread Notifications: {response.status_code} - {response.json()}")

# %%
# 14.3: GET /api/v1/notifications/unread_count/ - Get count of unread notifications
response = requests.get(f"{BASE}/api/v1/notifications/unread_count/", headers=headers)
print(f"14.3 Unread Count: {response.status_code} - {response.json()}")

# %%
# 14.4: GET /api/v1/notifications/{notification_1_id}/ - Get notification details
notification_1_id = 1  # Assuming notification exists
response = requests.get(f"{BASE}/api/v1/notifications/{notification_1_id}/", headers=headers)
print(f"14.4 Notification Details: {response.status_code} - {response.json()}")

# %%
# 14.5: DELETE /api/v1/notifications/{notification_1_id}/ - Delete notification
response = requests.delete(f"{BASE}/api/v1/notifications/{notification_1_id}/", headers=headers)
print(f"14.5 Delete Notification: {response.status_code} - {response.json()}")

# %%
# 14.6: POST /api/v1/notifications/{notification_1_id}/mark_as_read/ - Mark notification as read
response = requests.post(f"{BASE}/api/v1/notifications/{notification_1_id}/mark_as_read/", headers=headers)
print(f"14.6 Mark as Read: {response.status_code} - {response.json()}")

# %%
# 14.7: POST /api/v1/notifications/mark_all_as_read/ - Mark all notifications as read
response = requests.post(f"{BASE}/api/v1/notifications/mark_all_as_read/", headers=headers)
print(f"14.7 Mark All as Read: {response.status_code} - {response.json()}")

# %%
# 14.8: POST /api/v1/notifications/bulk_delete/ - Bulk delete notifications
bulk_delete_data = {"notification_ids": [1, 2]}
response = requests.post(f"{BASE}/api/v1/notifications/bulk_delete/", json=bulk_delete_data, headers=headers)
print(f"14.8 Bulk Delete: {response.status_code} - {response.json()}")

# %%
# 15.1: GET /api/v1/reports/reports/ - List all reports
response = requests.get(f"{BASE}/api/v1/reports/reports/", headers=headers)
print(f"15.1 List Reports: {response.status_code} - {response.json()}")

# %%
# 15.2: POST /api/v1/reports/reports/ - Create report
report_data = {"report_type": "usage", "date_range": {"start": "2024-01-01", "end": "2024-01-31"}}
response = requests.post(f"{BASE}/api/v1/reports/reports/", json=report_data, headers=headers)
report_1_id = response.json().get("id")
print(f"15.2 Create Report: {response.status_code} - Report ID: {report_1_id}")

# %%
# 15.3: GET /api/v1/reports/reports/{report_1_id}/ - Get report details
response = requests.get(f"{BASE}/api/v1/reports/reports/{report_1_id}/", headers=headers)
print(f"15.3 Report Details: {response.status_code} - {response.json()}")

# %%
# 15.4: PUT /api/v1/reports/reports/{report_1_id}/ - Full update report
update_report_data = {"status": "archived", "notes": "Monthly usage report"}
response = requests.put(f"{BASE}/api/v1/reports/reports/{report_1_id}/", json=update_report_data, headers=headers)
print(f"15.4 Update Report (PUT): {response.status_code} - {response.json()}")

# %%
# 15.5: PATCH /api/v1/reports/reports/{report_1_id}/ - Partial update report
patch_report_data = {"notes": "Reviewed"}
response = requests.patch(f"{BASE}/api/v1/reports/reports/{report_1_id}/", json=patch_report_data, headers=headers)
print(f"15.5 Update Report (PATCH): {response.status_code} - {response.json()}")

# %%
# 15.6: DELETE /api/v1/reports/reports/{report_1_id}/ - Delete report - SKIPPED
print("15.6 Delete Report: SKIPPED (keeping for download test)")

# %%
# 15.7: GET /api/v1/reports/reports/{report_1_id}/download/ - Download report file
response = requests.get(f"{BASE}/api/v1/reports/reports/{report_1_id}/download/", headers=headers)
print(f"15.7 Download Report: {response.status_code} - Content-Type: {response.headers.get('Content-Type')}")

# %%
# 15.8: GET /api/v1/reports/reports/stats/ - Get report statistics
response = requests.get(f"{BASE}/api/v1/reports/reports/stats/", headers=headers)
print(f"15.8 Report Stats: {response.status_code} - {response.json()}")

# %%
# 15.9: POST /api/v1/reports/reports/cleanup_expired/ - Cleanup old expired reports
response = requests.post(f"{BASE}/api/v1/reports/reports/cleanup_expired/", headers=headers)
print(f"15.9 Cleanup Expired: {response.status_code} - {response.json()}")

# %%
# 16.1: GET /api/v1/reports/schedules/ - List all report schedules
response = requests.get(f"{BASE}/api/v1/reports/schedules/", headers=headers)
print(f"16.1 List Schedules: {response.status_code} - {response.json()}")

# %%
# 16.2: POST /api/v1/reports/schedules/ - Create report schedule
schedule_data = {"report_type": "usage", "frequency": "weekly", "day_of_week": 1}
response = requests.post(f"{BASE}/api/v1/reports/schedules/", json=schedule_data, headers=headers)
schedule_1_id = response.json().get("id")
print(f"16.2 Create Schedule: {response.status_code} - Schedule ID: {schedule_1_id}")

# %%
# 16.3: GET /api/v1/reports/schedules/{schedule_1_id}/ - Get schedule details
response = requests.get(f"{BASE}/api/v1/reports/schedules/{schedule_1_id}/", headers=headers)
print(f"16.3 Schedule Details: {response.status_code} - {response.json()}")

# %%
# 16.4: PUT /api/v1/reports/schedules/{schedule_1_id}/ - Full update schedule
update_schedule_data = {"report_type": "usage", "frequency": "monthly", "day_of_month": 1}
response = requests.put(f"{BASE}/api/v1/reports/schedules/{schedule_1_id}/", json=update_schedule_data, headers=headers)
print(f"16.4 Update Schedule (PUT): {response.status_code} - {response.json()}")

# %%
# 16.5: PATCH /api/v1/reports/schedules/{schedule_1_id}/ - Partial update schedule
patch_schedule_data = {"is_active": False}
response = requests.patch(f"{BASE}/api/v1/reports/schedules/{schedule_1_id}/", json=patch_schedule_data, headers=headers)
print(f"16.5 Update Schedule (PATCH): {response.status_code} - {response.json()}")

# %%
# 16.6: DELETE /api/v1/reports/schedules/{schedule_1_id}/ - Delete schedule - SKIPPED
print("16.6 Delete Schedule: SKIPPED (keeping for action tests)")

# %%
# 16.7: POST /api/v1/reports/schedules/{schedule_1_id}/activate/ - Activate schedule
response = requests.post(f"{BASE}/api/v1/reports/schedules/{schedule_1_id}/activate/", headers=headers)
print(f"16.7 Activate Schedule: {response.status_code} - {response.json()}")

# %%
# 16.8: POST /api/v1/reports/schedules/{schedule_1_id}/deactivate/ - Deactivate schedule
response = requests.post(f"{BASE}/api/v1/reports/schedules/{schedule_1_id}/deactivate/", headers=headers)
print(f"16.8 Deactivate Schedule: {response.status_code} - {response.json()}")

# %%
# 16.9: POST /api/v1/reports/schedules/{schedule_1_id}/run_now/ - Manually trigger schedule
response = requests.post(f"{BASE}/api/v1/reports/schedules/{schedule_1_id}/run_now/", headers=headers)
print(f"16.9 Run Schedule Now: {response.status_code} - {response.json()}")

# %%
# 16.10: GET /api/v1/reports/schedules/pending/ - Get pending scheduled reports
response = requests.get(f"{BASE}/api/v1/reports/schedules/pending/", headers=headers)
print(f"16.10 Pending Schedules: {response.status_code} - {response.json()}")

# %%
# 17.1: POST /webhooks/telegram/ - Receive Telegram webhook
telegram_webhook_data = {"update_id": 123, "message": {"text": "Hello", "from": {"id": 456}}}
response = requests.post(f"{BASE}/webhooks/telegram/", json=telegram_webhook_data)
print(f"17.1 Telegram Webhook: {response.status_code} - {response.json()}")

# %%
# 17.2: POST /webhooks/instagram/ - Receive Instagram webhook
instagram_webhook_data = {"object": "instagram", "entry": [{"messaging": [{"message": {"text": "Hi"}}]}]}
response = requests.post(f"{BASE}/webhooks/instagram/", json=instagram_webhook_data)
print(f"17.2 Instagram Webhook: {response.status_code} - {response.json()}")

# %%
# 17.3: POST /webhooks/whatsapp/ - Receive WhatsApp webhook
whatsapp_webhook_data = {"messages": [{"from": "+1234567890", "text": {"body": "Hello"}}]}
response = requests.post(f"{BASE}/webhooks/whatsapp/", json=whatsapp_webhook_data)
print(f"17.3 WhatsApp Webhook: {response.status_code} - {response.json()}")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Project/telSMS/telegram-sender-django/.venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
# 17.4: POST /webhooks/sms/ - Receive SMS webhook
sms_webhook_data = {"From": "+1234567890", "Body": "Test SMS", "MessageSid": "SM123"}
response = requests.post(f"{BASE}/webhooks/sms/", json=sms_webhook_data)
print(f"17.4 SMS Webhook: {response.status_code} - {response.json()}")

# %%
# 17.5: POST /webhooks/stripe/ - Receive Stripe payment webhook
stripe_webhook_data = {"type": "charge.succeeded", "data": {"object": {"amount": 5000}}}
response = requests.post(f"{BASE}/webhooks/stripe/", json=stripe_webhook_data)
print(f"17.5 Stripe Webhook: {response.status_code} - {response.json()}")

# %%
# 17.6: GET /webhooks/logs/ - List all webhook logs (admin only)
response = requests.get(f"{BASE}/webhooks/logs/", headers=headers)
print(f"17.6 List Webhook Logs: {response.status_code} - {response.json()}")

# %%
# 17.7: GET /webhooks/logs/{log_1_id}/ - Get specific webhook log details
log_1_id = 1  # Assuming log exists
response = requests.get(f"{BASE}/webhooks/logs/{log_1_id}/", headers=headers)
print(f"17.7 Webhook Log Details: {response.status_code} - {response.json()}")

# %%
# 17.8: DELETE /webhooks/logs/{log_1_id}/ - Delete webhook log (admin only)
response = requests.delete(f"{BASE}/webhooks/logs/{log_1_id}/", headers=headers)
print(f"17.8 Delete Webhook Log: {response.status_code} - {response.json()}")

# %%
# 17.9: GET /webhooks/logs/failed/ - Get failed webhook logs
response = requests.get(f"{BASE}/webhooks/logs/failed/", headers=headers)
print(f"17.9 Failed Webhook Logs: {response.status_code} - {response.json()}")

# %%
# 17.10: GET /webhooks/logs/unprocessed/ - Get unprocessed webhook logs
response = requests.get(f"{BASE}/webhooks/logs/unprocessed/", headers=headers)
print(f"17.10 Unprocessed Webhook Logs: {response.status_code} - {response.json()}")
# Out:
# 17.10 Unprocessed Webhook Logs: 403 - {'detail': 'You do not have permission to perform this action.'}

# %%
# 17.11: GET /webhooks/logs/stats/ - Get webhook statistics
response = requests.get(f"{BASE}/webhooks/logs/stats/", headers=headers)
print(f"17.11 Webhook Stats: {response.status_code} - {response.json()}")
# Out:
# 17.11 Webhook Stats: 403 - {'detail': 'You do not have permission to perform this action.'}

# %%
# 17.12: POST /webhooks/logs/{log_1_id}/retry/ - Retry failed webhook processing
response = requests.post(f"{BASE}/webhooks/logs/{log_1_id}/retry/", headers=headers)
print(f"17.12 Retry Webhook: {response.status_code} - {response.json()}")

# %%
# 17.13: POST /webhooks/logs/retry_multiple/ - Retry multiple failed webhooks
retry_multiple_data = {"log_ids": [2, 3]}
response = requests.post(f"{BASE}/webhooks/logs/retry_multiple/", json=retry_multiple_data, headers=headers)
print(f"17.13 Retry Multiple Webhooks: {response.status_code} - {response.json()}")

# %% [markdown]
# ## 18. Cleanup & Logout

# %% [markdown]
# ### POST /api/v1/auth/logout/ - Logout admin user
# Headers: `Authorization: Token {admin_token}` → Response: `{message: "Logged out successfully"}`
# ---
# ## Summary
# ✅ **All 150+ API endpoints covered** for Admin User scenario including:
# - 14 Auth/User Management endpoints
# - 8 Transaction endpoints
# - 18 Package/Subscription/Usage endpoints
# - 10 Telegram Account endpoints
# - 6 Instagram Account endpoints
# - 6 Twilio Account endpoints
# - 6 WhatsApp Account endpoints
# - 10 Unified Platform Account endpoints
# - 15 Company/Membership endpoints
# - 10 Template endpoints
# - 7 Send Message endpoints
# - 9 Message Management endpoints
# - 10 Conversation endpoints
# - 8 Notification endpoints
# - 9 Report endpoints
# - 10 Report Schedule endpoints
# - 13 Webhook endpoints
# **Total: 169 unique API endpoint calls demonstrated**
# All operations performed with full admin privileges. Admin can view/modify all system resources, perform refunds, access logs, and manage users/companies.
